# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('CleanData_new .csv')

# %%
df.shape
# Out:
# (4888, 20)

# %% [markdown]
# NULL Values : Replace numerical values with a mean and other categorical values using mode.

# %%
sns.countplot(x='TypeofContact' ,data=df,hue = df['ProdTaken'])
# Out:
# <AxesSubplot:xlabel='TypeofContact', ylabel='count'>

# %%
sns.countplot(x='Occupation',data=df,hue = 'ProdTaken')
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(x='NumberOfPersonVisiting',data=df,hue = 'ProdTaken')
# Out:
# <AxesSubplot:xlabel='NumberOfPersonVisiting', ylabel='count'>

# %%
sns.countplot(x='MaritalStatus',data=df,hue = 'ProdTaken')
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %%
sns.histplot(x='DurationOfPitch',data=df[df['ProdTaken']==0],hue = 'ProdTaken')
# Out:
# <AxesSubplot:xlabel='DurationOfPitch', ylabel='Count'>

# %%
sns.countplot(x='ProductPitched',data=df,hue = 'ProdTaken')
# Out:
# <AxesSubplot:xlabel='ProductPitched', ylabel='count'>

# %%
sns.countplot(x='PitchSatisfactionScore',data=df,hue = 'Gender')
# Out:
# <AxesSubplot:xlabel='PitchSatisfactionScore', ylabel='count'>

# %%
sns.countplot(x='PitchSatisfactionScore',data=df,hue = 'ProdTaken')
# Out:
# <AxesSubplot:xlabel='PitchSatisfactionScore', ylabel='count'>

# %%
sns.scatterplot(x='Age',y='MonthlyIncome',data=df,hue = 'ProdTaken')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='MonthlyIncome'>
